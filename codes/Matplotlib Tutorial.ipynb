# %% [markdown]
# # Matplotlib tutorial
# ### Author: Shivam Verma
# ### Date: 11 Feb. 2022
# ### Institute: RKMVERI, Belur

# %%
import numpy as np #for working with arrays
import pandas as pd #for dataframes
import matplotlib.pyplot as plt #To plot using abbreviation 'plt'

# %% [markdown]
# # Basic

# %% [markdown]
# Before plotting anything, we start by creating a figure and an axes.

# %% [markdown]
# **Figure** : An instance of the class ``plt.Figure`` - a container that contains all the objects representing axes, graphics, text, and labels

# %% [markdown]
# **Axes**: An instance of the class ``plt.Axes``- It's bounding box with ticks and labels, which will contain the plot elements.

# %%
fig = plt.figure()
ax = plt.axes()

# %% [markdown]
# # Line plot

# %% [markdown]
# One of the elementary plotting is the visualize a single function $y = f(x)$.

# %%
x = np.linspace(0, 10, 100) #create an array of 100 linearly spaces x values in the range 0-100
y = np.sin(x) #compute the sine of the values xreated in in 'x'


fig = plt.figure()
ax = plt.axes()
ax.plot(x,y)

# %% [markdown]
# Notice the line ``[<matplotlib.lines.Line2D at 0x7f83ef7bc5e0>]`` in code output?
# That’s because Matplotlib returns the plot object itself besides drawing the plot.

# %% [markdown]
# We can also use ``plt`` directly to plot, in this case the figure and axes will be automatically created for us

# %%
ax.plot(x,np.sin(x))

# %%
plt.plot(x,np.cos(x))

# %% [markdown]
# If we want to create multiple curves on a single figure, we can call the ``plot`` function multiple times.
# Also, we can club the call for ``figure`` and ``axes`` by simply writing ``plt.subplot()``.

# %%
fig,ax = plt.subplots() 
 
ax.plot(x,np.sin(x))
ax.plot(x,np.cos(x))

# %% [markdown]
# ``plt.subplots`` returns a tuple containing a figure and axes object

# %% [markdown]
# # Controlling aesthetics of the Plot: Line Colors and Styles

# %% [markdown]
# ## Linestyle

# %% [markdown]
# First adjustment we do is of ``line style`` of the plot. To adjust the linestyle, we can use the ``style`` keyword.

# %%
plt.plot(x, (x+1)**2 , linestyle='solid')
plt.plot(x, (x+2)**2 , linestyle='dashed')
plt.plot(x, (x+3)**2 , linestyle='dashdot')
plt.plot(x, (x+3)**2 , linestyle='dotted')

# Or just use the symbol version
plt.plot(x, (x+ 4)**2, linestyle='-')  # solid
plt.plot(x, (x+5)**2 , linestyle='--') # dashed
plt.plot(x, (x+6)**2 , linestyle='-.') # dashdot
plt.plot(x, (x+7)**2 , linestyle=':'); # dotted

# %% [markdown]
# ## Line color

# %% [markdown]
# Second comes the ``color`` of the plot. To adjust the color, we can use the ``color`` keyword, which accepts a string argument representing any imaginable color. we have amny ways to invoke this:

# %%
plt.plot(x, np.sin(x - 0), color='blue')        # specify color by name
plt.plot(x, np.sin(x - 1), color='g')           # short color code (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75')        # Grayscale between 0 and 1
plt.plot(x, np.sin(x - 3), color='#FFDD44')     # Hex code (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB tuple, values 0 to 1
plt.plot(x, np.sin(x - 5), color='chartreuse'); # all HTML color names supported

# %% [markdown]
# ## Labelling

# %%
plt.plot(x, x**2)
plt.title("Parabola")
plt.xlabel("x")
plt.ylabel("x**2");

# %% [markdown]
# To add latex symbols and to have latex look to you labelling add ``r`` before label ``"``

# %%
plt.plot(x, x**2)
plt.title("Parabola")
plt.xlabel(r"$x$")
plt.ylabel(r'$x^{2}$');

# %% [markdown]
# ## Adjusting axes

# %%
plt.plot(x, np.sin(x));

# %% [markdown]
# To control the axis limits we use the ``plt.xlim()`` and ``plt.ylim()`` methods:

# %%
plt.plot(x, np.sin(x))

plt.xlim(0, 10)
plt.ylim(1.5, -1.5);

# %% [markdown]
# We can adjust the  plot axis limits in one go with ``plt.axis``, not to be confused with ``plt.axes``

# %%
plt.plot(x, np.sin(x))
plt.axis([0, 2*np.pi, -1.5, 1.5]);

# %% [markdown]
# ## Adding Legends

# %% [markdown]
# Matplotlib has a built-in way of quickly creating a legend. By calling ``plt.legend()`` method and specify the keyword ``label`` when plotting a function:

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.axis('equal')

plt.legend();

# %% [markdown]
# ## plt to ax
#
# Most``plt`` functions translate directly to ``ax`` methods but this is not true for all commands.
# For eg. setting limits, labels, and titles are slightly modified.
#
# - ``plt.xlabel()``  → ``ax.set_xlabel()``
# - ``plt.ylabel()`` → ``ax.set_ylabel()``
# - ``plt.xlim()``  → ``ax.set_xlim()``
# - ``plt.ylim()`` → ``ax.set_ylim()``
# - ``plt.title()`` → ``ax.set_title()``
#
# It is often more convenient to use the ``ax.set()`` method to set all these properties at once:

# %%
ax = plt.axes()
ax.set(xlim=(0, 10), ylim=(-1.5, 1.5),xlabel='x', ylabel='sin(x)',title='Sine Plot')
ax.plot(x, np.sin(x));

# %% [markdown]
# # Scatter plot

# %%
plt.plot(x, np.sin(x), 'o');

# %% [markdown]
# One way of creating scatter plots is the ``plt.scatter`` function, which can be used very similarly to the ``plt.plot`` function:

# %%
plt.scatter(x, y, marker='o');

# %% [markdown]
# The difference of ``plt.scatter`` from ``plt.plot`` is that it can be used to create scatter plots where the properties of each individual point (size, face color, edge color, etc.) can be individually controlled or mapped to data.

# %%
np.random.randint(10,100,(1,100)).flatten()
# Out:
# array([86, 62, 42, 90, 89, 96, 35, 98, 32, 68, 75, 38, 45, 10, 21, 47, 82,
#        79, 58, 98, 10, 67, 34, 95, 91, 11, 23, 84, 35, 40, 29, 78, 57, 63,
#        49, 66, 38, 92, 67, 93, 86, 76, 45, 17, 50, 95, 33, 92, 40, 12, 87,
#        96, 67, 35, 34, 36, 20, 93, 74, 19, 18, 83, 33, 44, 89, 20, 54, 16,
#        26, 73, 42, 14, 21, 98, 70, 47, 65, 15, 68, 83, 99, 61, 21, 81, 95,
#        46, 59, 61, 55, 59, 66, 79, 67, 45, 47, 33, 42, 35, 93, 72])

# %%
rnd =  np.random.RandomState(0)
x1 = rnd.randn(100)
y1 =  rnd.randn(100)
colors =rnd.rand(100)
sizes = 1000 *rnd.rand(100)

#randn generates samples from the normal distribution, 
#rand from a uniform distribution in the range [0,1)

plt.scatter(x1, y1, c=colors, s=sizes, alpha=0.3,
            cmap='viridis')
plt.colorbar();  # show color scale

# %% [markdown]
# Why might you choose to use one over the other? While it doesn't matter as much for small amounts of data, as datasets get larger than a few thousand points, ``plt.plot`` can be noticeably more efficient than ``plt.scatter``.
# The reason is that ``plt.scatter`` has the capability to render a different size and/or color for each point, so the renderer must do the extra work of constructing each point individually.
# In ``plt.plot``, on the other hand, the points are always essentially clones of each other, so the work of determining the appearance of the points is done only once for the entire set of data.
# For large datasets, the difference between these two can lead to vastly different performance, and for this reason, ``plt.plot`` should be preferred over ``plt.scatter`` for large datasets.

# %% [markdown]
# ## Scaling axis

# %%
ax = plt.axes()
ax.set(xlabel='x', ylabel='log(x+1)',title='Logarithm Plot')
ax.set_yscale('log')
ax.plot(x, np.log(x+1));

# %%
x = np.linspace(0, np.pi*2, 100)
  
# Initialise the subplot function using number of rows and columns
figure, axis = plt.subplots(2, 2,figsize=(9, 9)) 
# For sine Function
axis[0, 0].plot(x, np.sin(x))
axis[0, 0].set_title("Sine Function")
 
# For cosine Function
axis[0, 1].plot(x, np.cos(x))
axis[0, 1].set_title("Cosine Function")
  
# For tan Function
axis[1, 0].plot(x, np.tan(x))
axis[1, 0].set_title("Tangent Function")
  
# For sinh Function
axis[1, 1].plot(x, np.sinh(x))
axis[1, 1].set_title("sinh Function")

plt.show()

# %% [markdown]
# # Importing data and visualizing

# %%
# Using Pandas
df = pd.read_csv('all.dat', sep="\t", names=['$x$','$x^{2}/16$','$\sin(x)$','$\exp(x)$'],header = None)
df
# Out:
#           $x$  $x^{2}/16$  $\sin(x)$     $\exp(x)$
# 0  -10.000000    6.250000   0.544021      0.000045
# 1   -9.797980    6.000026   0.364599      0.000056
# 2   -9.595960    5.755153   0.170347      0.000068
# 3   -9.393939    5.515381  -0.030834      0.000083
# 4   -9.191919    5.280711  -0.230760      0.000102
# ..        ...         ...        ...           ...
# 95   9.191919    5.280711   0.230760   9817.474528
# 96   9.393939    5.515381   0.030834  12015.339378
# 97   9.595960    5.755153  -0.170347  14705.246237
# 98   9.797980    6.000026  -0.364599  17997.349895
# 99  10.000000    6.250000  -0.544021  22026.465795
#
# [100 rows x 4 columns]

# %%
fig,ax = plt.subplots(1,1,figsize = (7,5))
ax.set(xlabel='x', ylabel='$sin(x)$',title='Sine Plot')
ax.plot(df['$x$'], df['$\sin(x)$']);

# %% [markdown]
# # Colormap

# %%
xc = np.linspace(0, 10, 1000)
I = np.sin(xc) * np.cos(xc[:, np.newaxis])

fig,ax = plt.subplots(1,1,figsize=(7,5))
im = ax.imshow(I,cmap = "rainbow")
fig.colorbar(im);

# %% [markdown]
# Reference: https://colab.research.google.com/github/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/Index.ipynb#scrollTo=r3brvx-ygtgu
